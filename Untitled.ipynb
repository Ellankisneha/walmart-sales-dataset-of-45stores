# %%
import pandas as pd

# Load the dataset
data = pd.read_csv("walmart-sales-dataset-of-45stores.csv")

# Display the first few rows of the dataset
print(data.head())

# Summary statistics of the numerical variables
print(data.describe())

# Check for missing values
print(data.isnull().sum())
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05-02-2010    1643690.90             0        42.31       2.572
# 1      1  12-02-2010    1641957.44             1        38.51       2.548
# 2      1  19-02-2010    1611968.17             0        39.93       2.514
# 3      1  26-02-2010    1409727.59             0        46.63       2.561
# 4      1  05-03-2010    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106
#              Store  Weekly_Sales  Holiday_Flag  Temperature   Fuel_Price  \
# count  6435.000000  6.435000e+03   6435.000000  6435.000000  6435.000000
# mean     23.000000  1.046965e+06      0.069930    60.663782     3.358607
# std      12.988182  5.643666e+05      0.255049    18.444933     0.459020
# ...

# %%
print(data.columns)
# Out:
# Index(['Store', 'Date', 'Weekly_Sales', 'Holiday_Flag', 'Temperature',
#        'Fuel_Price', 'CPI', 'Unemployment'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# Plotting a histogram of weekly sales
plt.figure(figsize=(10, 6))
plt.hist(data['Weekly_Sales'], bins=20, color='skyblue', edgecolor='black')
plt.title('Distribution of Weekly Sales')
plt.xlabel('Weekly Sales')
plt.ylabel('Frequency')
plt.show()

# %%
# Plotting a scatter plot of temperature vs. yield
plt.figure(figsize=(8, 6))
plt.scatter(data['CPI'], data['Store'], color='green', alpha=0.5)
plt.title('CPIe vs. Store')
plt.xlabel('CPI')
plt.ylabel('Store')
plt.grid(True)
plt.show()

# %%
# Drop the 'Date' column before calculating the correlation matrix
data_numeric = data.drop(columns=['Date'])

# Calculating the correlation matrix
correlation_matrix = data_numeric.corr()

# Plotting the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Walmart Sales Dataset')
plt.xlabel('Features')
plt.ylabel('Features')
plt.show()
